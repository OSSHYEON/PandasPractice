# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/worldcup/worldcupgoals.csv")
df.head()
# Out:
#            Player  Goals                Years  Country
# 0  Miroslav Klose     16  2002-2006-2010-2014  Germany
# 1         Ronaldo     15       1998-2002-2006   Brazil
# 2     Gerd Muller     14            1970-1974  Germany
# 3   Just Fontaine     13                 1958   France
# 4            Pele     12  1958-1962-1966-1970   Brazil

# %% [markdown]
# ---

# %% [markdown]
# ### 1. 주어진 전체 기간의 각 나라별 골득 점수 상위 5개 국가와 그 득점 수를 데이터 프레임 형태로 출력하라

# %%
df.groupby('Country').sum().sort_values('Goals', ascending=False).head()
# Out:
#            Goals
# Country
# Brazil       228
# Germany      226
# Argentina    135
# Italy        123
# France       115

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Years 컬럼은 년도 - 년도 형식으로 구성되어 있고, 각 년도는 4자리 숫자이다. <br><br> 년도 표기가 4자리 숫자로 안된 케이스가 존재한다. 해당 건은 몇 건인지 출력하라

# %%
df['year_list'] = df.Years.str.split('-')

# %%
def checkFour(x):
    for value in x:
        if len(str(value)) != 4:
            return False
    return True

df['check'] = df['year_list'].apply(checkFour)
result = len(df[df.check==False])
result
# Out:
# 45

# %% [markdown]
# ---

# %% [markdown]
# ### 3. Q3에서 발생한 예외 케이스를 제외한 데이터 프레임을 df2라고 정의하고, <br><br> 데이터의 행 숫자를 출력하라.

# %%
df2 = df[df.check==True].reset_index(drop=True)
df2.shape[0]
# Out:
# 1250

# %% [markdown]
# ---

# %% [markdown]
# ### 4. 월드컵 출전 횟수를 나타내는 LenCup 컬럼을 추가하고, 4회 출전한 선수의 숫자를 구하여라

# %%
df2.head()
# Out:
#            Player  Goals                Years  Country  \
# 0  Miroslav Klose     16  2002-2006-2010-2014  Germany
# 1         Ronaldo     15       1998-2002-2006   Brazil
# 2     Gerd Muller     14            1970-1974  Germany
# 3   Just Fontaine     13                 1958   France
# 4            Pele     12  1958-1962-1966-1970   Brazil
#
#                   year_list  check
# 0  [2002, 2006, 2010, 2014]   True
# 1        [1998, 2002, 2006]   True
# 2              [1970, 1974]   True
# 3                    [1958]   True
# 4  [1958, 1962, 1966, 1970]   True

# %%
df2['LenCup'] = df2['year_list'].str.len()
df2
# Out:
#                    Player  Goals                Years     Country  \
# 0          Miroslav Klose     16  2002-2006-2010-2014     Germany
# 1                 Ronaldo     15       1998-2002-2006      Brazil
# 2             Gerd Muller     14            1970-1974     Germany
# 3           Just Fontaine     13                 1958      France
# 4                    Pele     12  1958-1962-1966-1970      Brazil
# ...                   ...    ...                  ...         ...
# 1245        Josip Skoblar      1                 1962  Yugoslavia
# 1246          Safet Susic      1            1982-1990  Yugoslavia
# 1247  Aleksandar Tirnanic      1                 1930  Yugoslavia
# 1248  Djordje Vujadinovic      1                 1930  Yugoslavia
# 1249         Branko Zebec      1            1954-1958  Yugoslavia
#
#                      year_list  check  LenCup
# 0     [2002, 2006, 2010, 2014]   True       4
# 1           [1998, 2002, 2006]   True       3
# ...

# %%
result = df2['LenCup'].value_counts()
result
# Out:
# 1    779
# 2    353
# 3    102
# 4     16
# Name: LenCup, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### 5. 유고슬라비아 국가의 월드컵 출전 횟수가 2회인 선수들의 숫자를 구하여라

# %%
df2.head()
# Out:
#            Player  Goals                Years  Country  \
# 0  Miroslav Klose     16  2002-2006-2010-2014  Germany
# 1         Ronaldo     15       1998-2002-2006   Brazil
# 2     Gerd Muller     14            1970-1974  Germany
# 3   Just Fontaine     13                 1958   France
# 4            Pele     12  1958-1962-1966-1970   Brazil
#
#                   year_list  check  LenCup
# 0  [2002, 2006, 2010, 2014]   True       4
# 1        [1998, 2002, 2006]   True       3
# 2              [1970, 1974]   True       2
# 3                    [1958]   True       1
# 4  [1958, 1962, 1966, 1970]   True       4

# %%
len(df2[(df2.LenCup==2)&(df2.Country=="Yugoslavia")])
# Out:
# 7

# %% [markdown]
# ---

# %% [markdown]
# ### 6. 2002년도에 출전한 전체 선수는 몇 명인가?

# %%
len(df2[df2.Years.str.contains('2002')])
# Out:
# 156

# %% [markdown]
# ---

# %% [markdown]
# ### 7. 이름에 carlos 단어가 들어가는 선수의 숫자는 몇 명인가?

# %%
df2[df2.Player.str.contains('carlos')]
# Out:
# Empty DataFrame
# Columns: [Player, Goals, Years, Country, year_list, check, LenCup]
# Index: []

# %%
len(df2[df2.Player.str.lower().str.contains('carlos')])
# Out:
# 13

# %% [markdown]
# ---

# %% [markdown]
# ### 8. 월드컵 출전 횟수가 1회 뿐인 선수 중에서 가장 많은 득점을 올렸던 선수는 누구인가?

# %%
df2.head()
# Out:
#            Player  Goals                Years  Country  \
# 0  Miroslav Klose     16  2002-2006-2010-2014  Germany
# 1         Ronaldo     15       1998-2002-2006   Brazil
# 2     Gerd Muller     14            1970-1974  Germany
# 3   Just Fontaine     13                 1958   France
# 4            Pele     12  1958-1962-1966-1970   Brazil
#
#                   year_list  check  LenCup
# 0  [2002, 2006, 2010, 2014]   True       4
# 1        [1998, 2002, 2006]   True       3
# 2              [1970, 1974]   True       2
# 3                    [1958]   True       1
# 4  [1958, 1962, 1966, 1970]   True       4

# %%
df2[df2.LenCup==1].sort_values('Goals', ascending=False).Player.values[0]
# Out:
# 'Just Fontaine'

# %% [markdown]
# ---

# %% [markdown]
# ### 9. 월드컵 출전 횟수가 1회 뿐인 선수들이 가장 많은 국가는 어디인가?

# %%
df2[df2.LenCup==1].Country.value_counts().index[0]
# Out:
# 'Brazil'
