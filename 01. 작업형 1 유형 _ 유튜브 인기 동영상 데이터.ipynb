# %%
import pandas as pd

# %%
pwd
# Out:
# '/home/work/데이터분석'

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv", index_col=0)
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %% [markdown]
# ### 1. 인기 동영상 제작 횟수가 많은 채널 상위 10개를 출력하라

# %%
answer = list(df.loc[df.channelId.isin(df.channelId.value_counts().head(10).index)].channelTitle.unique())
answer
# Out:
# ['장삐쭈',
#  '총몇명',
#  '파뿌리',
#  '짤툰',
#  '런닝맨 - 스브스 공식 채널',
#  '엠뚜루마뚜루 : MBC 공식 종합 채널',
#  'SPOTV',
#  '채널 십오야',
#  '이과장',
#  'BANGTANTV']

# %% [markdown]
# - isin() : 각각의 요소가 데이터 프레임 또는 시리즈에 있는지 확인하는 함수
#         어떤 리스트에 존재하는 요소가 대상 데이터 프레임이나 시리즈에 존재하는지 True, False로 반환해준다
# - value_counts() : 종류별 갯수를 세주는 함수.
#                    result1 = Series.value_counts(normalize=False, sort=True, ascending=False)
#                    result2 = Dataframe.value_counts(subset=None, normalize=False, sort=True, ascending=False)
#
#                    normalize, 기본값 False. True일 경우 요소별 개수가 아닌 비율로 변환해 출력한다.
#                    sort, 기본값 True. 결과에 대해 정렬 수행
#                    ascending, 기본값 False. True일 경우 오름차순으로 정렬한다.
#                    subset, 선택적 입력이 가능하며 고유한 열을 계산할 때 사용하는 열이다.
#
# - index : 인덱스 추출
# - unique() : 유일한 값(고유한 값) 찾기

# %%
a = df.channelId.value_counts().head()
a.describe()
# Out:
# count      5.000000
# mean     322.800000
# std       29.371755
# min      293.000000
# 25%      313.000000
# 50%      318.000000
# 75%      318.000000
# max      372.000000
# Name: channelId, dtype: float64

# %%
a.index.value_counts()
# Out:
# UCszFjh7CEfwDb7UUGb4RzCQ    1
# UClzB2iZ5jPoTNz0S-QU6Wiw    1
# UCtm_QoN2SIxwCE-59shX7Qg    1
# UCaKod3X1Tn4c7Ci0iUKcvzQ    1
# UCiwQRG2sCcfjKkgxMEdJGPg    1
# dtype: int64

# %%
a
# Out:
# UCszFjh7CEfwDb7UUGb4RzCQ    372
# UClzB2iZ5jPoTNz0S-QU6Wiw    318
# UCtm_QoN2SIxwCE-59shX7Qg    318
# UCaKod3X1Tn4c7Ci0iUKcvzQ    313
# UCiwQRG2sCcfjKkgxMEdJGPg    293
# Name: channelId, dtype: int64

# %%
df.channelId.isin(a)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 60394    False
# 60395    False
# 60396    False
# 60397    False
# 60398    False
# Name: channelId, Length: 60399, dtype: bool

# %%
df.loc[df.channelId.isin(df.channelId.value_counts().head(10).index)].channelTitle.unique()
# Out:
# array(['장삐쭈', '총몇명', '파뿌리', '짤툰', '런닝맨 - 스브스 공식 채널',
#        '엠뚜루마뚜루 : MBC 공식 종합 채널', 'SPOTV', '채널 십오야', '이과장', 'BANGTANTV'],
#       dtype=object)

# %%
list(df.loc[df.channelId.isin(df.channelId.value_counts().head(10).index)].channelTitle.unique())
# Out:
# ['장삐쭈',
#  '총몇명',
#  '파뿌리',
#  '짤툰',
#  '런닝맨 - 스브스 공식 채널',
#  '엠뚜루마뚜루 : MBC 공식 종합 채널',
#  'SPOTV',
#  '채널 십오야',
#  '이과장',
#  'BANGTANTV']

# %% [markdown]
# ------------------------------------------------

# %% [markdown]
# ### 2. 논란으로 인기 동영상이 된 케이스를 확인하고 싶다. 싫어요 수가 좋아요 수보다 높은 동영상을 제작한 채널을 모두 출력하라

# %%
answer = list(df.loc[df.dislikes > df.likes].channelTitle.unique())
answer
# Out:
# ['핫도그TV',
#  'ASMR 애정TV',
#  '하얀트리HayanTree',
#  '양팡 YangPang',
#  '철구형 (CHULTUBE)',
#  '왜냐맨하우스',
#  '(MUTUBE)와꾸대장봉준',
#  '오메킴TV',
#  '육지담',
#  'MapleStory_KR',
#  'ROAD FIGHTING CHAMPIONSHIP',
#  '사나이 김기훈',
#  '나혼자산다 STUDIO',
#  'Gen.G esports']

# %%
len(answer)
# Out:
# 14

# %% [markdown]
# ------------

# %% [markdown]
# ### 3. 채널명을 바꾼 케이스가 있는지 확인하고 싶다. channelId의 경우 고유값이다. <br><br>이를 통해 채널명을 한 번이라도 바꾼 채널 갯수를 구하여라.

# %%
change = df[['channelTitle', 'channelId']].drop_duplicates().channelId.value_counts()
target = change[change > 1]
len(target)
# Out:
# 71

# %%
df['channelTitle']
# Out:
# 0                            장삐쭈
# 1        RAIN's Official Channel
# 2                    서울시 · Seoul
# 3                   고기남자 MeatMan
# 4                          스브스밥집
#                   ...
# 60394                         공룡
# 60395                    놀면 뭐하니?
# 60396          김종국 GYM JONG KOOK
# 60397                   스브스 예능맛집
# 60398                HYBE LABELS
# Name: channelTitle, Length: 60399, dtype: object

# %%
df['channelId']
# Out:
# 0        UChbE5OZQ6dRHECsX0tEPEZQ
# 1        UCxXgIeE5hxWxHG6dz9Scg2w
# 2        UCZUPZW5idAxYp-Asj__lVAA
# 3        UCT3CumbFIJiW33uq0UI3zlg
# 4        UCdWgRSfttvDucq4ApcCg5Mw
#                    ...
# 60394    UCWf4QKgnTyvmehcRqw-JldQ
# 60395    UCx6jsZ02B4K3SECUrkgPyzg
# 60396    UCoe-0EVDJnjlSoPK8ygcGwQ
# 60397    UCnx4Fi4cmkLGDiFfZ311wWw
# 60398    UC3IZKseVpdzPSBaWxBxundA
# Name: channelId, Length: 60399, dtype: object

# %%
df[['channelTitle', 'channelId']]
# Out:
#                   channelTitle                 channelId
# 0                          장삐쭈  UChbE5OZQ6dRHECsX0tEPEZQ
# 1      RAIN's Official Channel  UCxXgIeE5hxWxHG6dz9Scg2w
# 2                  서울시 · Seoul  UCZUPZW5idAxYp-Asj__lVAA
# 3                 고기남자 MeatMan  UCT3CumbFIJiW33uq0UI3zlg
# 4                        스브스밥집  UCdWgRSfttvDucq4ApcCg5Mw
# ...                        ...                       ...
# 60394                       공룡  UCWf4QKgnTyvmehcRqw-JldQ
# 60395                  놀면 뭐하니?  UCx6jsZ02B4K3SECUrkgPyzg
# 60396        김종국 GYM JONG KOOK  UCoe-0EVDJnjlSoPK8ygcGwQ
# 60397                 스브스 예능맛집  UCnx4Fi4cmkLGDiFfZ311wWw
# 60398              HYBE LABELS  UC3IZKseVpdzPSBaWxBxundA
#
# [60399 rows x 2 columns]

# %% [markdown]
# - duplicated() : 중복값 확인
# - drop_duplicates() : 중복값 처리

# %%
df[['channelTitle', 'channelId']].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 60394     True
# 60395     True
# 60396     True
# 60397     True
# 60398     True
# Length: 60399, dtype: bool

# %%
df[['channelTitle', 'channelId']].drop_duplicates()
# Out:
#                   channelTitle                 channelId
# 0                          장삐쭈  UChbE5OZQ6dRHECsX0tEPEZQ
# 1      RAIN's Official Channel  UCxXgIeE5hxWxHG6dz9Scg2w
# 2                  서울시 · Seoul  UCZUPZW5idAxYp-Asj__lVAA
# 3                 고기남자 MeatMan  UCT3CumbFIJiW33uq0UI3zlg
# 4                        스브스밥집  UCdWgRSfttvDucq4ApcCg5Mw
# ...                        ...                       ...
# 60023                      멸치형  UCsiuN8Jco3LbbuTyGuqRgKg
# 60028          키키TV, 전지적 예능 시점  UCRnEWJKVc5FpC-9Z3CBt2ZQ
# 60035                    기용이tv  UCkMN06eC97XL1qR1bExdwWg
# 60036       INSSAOPPA G [인싸오빠]  UCp9G3sWsE42Qo9jgnB1ta2Q
# 60068              한국닌텐도 공식 채널  UCRCK5FCJtomQT3b88jXI_DA
#
# [1843 rows x 2 columns]

# %%
a = df[['channelTitle', 'channelId']].drop_duplicates().channelId.value_counts()
a
# Out:
# UCtQYhzJWFai1y30UIA3uwYQ    3
# UC98TOxKQk4aLcx0EjIK0LkQ    3
# UC4nEQI74rZkFKlUSwi0ur4A    2
# UCn64fSqF2l4rkkjtQUpku2A    2
# UCjO3ji06DxmTM1RrzLVwmkA    2
#                            ..
# UCuZu8NrpBG4WPXRi-hPBl-A    1
# UCDrAR1OWC2MD4s0JLetN0MA    1
# UCx2MVBsdTJ_sv0LiUpSQU2Q    1
# UCu2R3TCLSxYV8pRyBGNOh2g    1
# UCRCK5FCJtomQT3b88jXI_DA    1
# Name: channelId, Length: 1770, dtype: int64

# %%
a>1
# Out:
# UCtQYhzJWFai1y30UIA3uwYQ     True
# UC98TOxKQk4aLcx0EjIK0LkQ     True
# UC4nEQI74rZkFKlUSwi0ur4A     True
# UCn64fSqF2l4rkkjtQUpku2A     True
# UCjO3ji06DxmTM1RrzLVwmkA     True
#                             ...
# UCuZu8NrpBG4WPXRi-hPBl-A    False
# UCDrAR1OWC2MD4s0JLetN0MA    False
# UCx2MVBsdTJ_sv0LiUpSQU2Q    False
# UCu2R3TCLSxYV8pRyBGNOh2g    False
# UCRCK5FCJtomQT3b88jXI_DA    False
# Name: channelId, Length: 1770, dtype: bool

# %%
target = a> 1
len(target)
# Out:
# 1770

# %%
target = a[a>1]
len(target)
# Out:
# 71

# %%
b = pd.DataFrame([[1, 2, 3],[4, 5, 6]])
b
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
b[b>1]
# Out:
#      0  1  2
# 0  NaN  2  3
# 1  4.0  5  6

# %%
b[b==2]
# Out:
#     0    1   2
# 0 NaN  2.0 NaN
# 1 NaN  NaN NaN

# %%
b>1
# Out:
#        0     1     2
# 0  False  True  True
# 1   True  True  True

# %% [markdown]
# ------------

# %% [markdown]
# ### 4. 일요일에 인기 있었던 영상 중 가장 많은 영상 종류는 무엇인가?

# %%
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
df['trending_date2'] = pd.to_datetime(df['trending_date2'])
df['trending_date2']
# Out:
# 0       2021-01-01
# 1       2021-01-01
# 2       2021-01-01
# 3       2021-01-01
# 4       2021-01-01
#            ...
# 60394   2021-10-19
# 60395   2021-10-19
# 60396   2021-10-19
# 60397   2021-10-19
# 60398   2021-10-19
# Name: trending_date2, Length: 60399, dtype: datetime64[ns]

# %%
df['trending_date2'].dt

# %% [markdown]
# - dt : Series 값의 date time like 속성에 대한 접근자 개체

# %%
df['trending_date2'].dt.day_name()
# Out:
# 0         Friday
# 1         Friday
# 2         Friday
# 3         Friday
# 4         Friday
#           ...
# 60394    Tuesday
# 60395    Tuesday
# 60396    Tuesday
# 60397    Tuesday
# 60398    Tuesday
# Name: trending_date2, Length: 60399, dtype: object

# %%
df['trending_date2'].dt.day_name() == "Sunday"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 60394    False
# 60395    False
# 60396    False
# 60397    False
# 60398    False
# Name: trending_date2, Length: 60399, dtype: bool

# %%
df.loc[df['trending_date2'].dt.day_name() == "Sunday"]
# Out:
#                                                    title         channelTitle  \
# 400    💎아형리미티드💎 [풀버전] 레전드의 레전드 무대! 박진영x비의 '나로 바꾸자'♬ (...     아는형님 Knowingbros
# 401                            27년 인생 첫 혼술 먹방 도중 방송사고가..                 뜨뜨뜨뜨
# 402    [2020 MBC 가요대제전] 비 X 박진영 - 나로 바꾸자 (RAIN X JYP ...              MBCkpop
# 403        MBC방송연예대상 2부 대환장 꿀잼 모먼트 #TVPP | MBC 201229 방송            TV-People
# 404               [EP114]※충격※모든 걸 잃고 한순간에 신용불량자 된 모델 지연수                푸하하TV
# ...                                                  ...                  ...
# 59994  [4K] 김필 (KIM FEEL)의 킬링보이스 - 그때 그 아인, 청춘, 얼음요새,...  딩고 뮤직 / dingo music
# 59995                                       [임영웅] 영웅의 휴가                  임영웅
# 59996  [예능연구소 4K] 키 1위 직캠 'BAD LOVE' (KEY No.1 Encore...              MBCkpop
# 59997                          내가 20대에 학원 원장이 될 수 있었던 이유                  박매일
# 59998                             흔한남매팀 라면 이상형 월드컵!ㅋㅋㅋㅋㅋ                 흔한일상
#
# ...

# %%
df.loc[df['trending_date2'].dt.day_name() == "Sunday"].categoryId
# Out:
# 400      24
# 401      22
# 402      10
# 403      24
# 404      24
#          ..
# 59994    10
# 59995    10
# 59996    10
# 59997    19
# 59998    24
# Name: categoryId, Length: 8600, dtype: int64

# %%
df.loc[df['trending_date2'].dt.day_name() == "Sunday"].categoryId.value_counts()
# Out:
# 24    3096
# 22    1337
# 10     830
# 17     636
# 23     556
# 25     437
# 26     363
# 20     289
# 1      274
# 15     217
# 27     199
# 28     167
# 2       99
# 19      91
# 29       9
# Name: categoryId, dtype: int64

# %%
df.loc[df['trending_date2'].dt.day_name() == "Sunday"].categoryId.value_counts().idxmax()
# Out:
# 24

# %% [markdown]
# ----

# %% [markdown]
# ### 5. 각 요일별 인기 영상들의 category Id는 각각 몇 개 씩인지 하나의 데이터 프레임으로 표현하라

# %%
df['trending_date2'].dt.day_name()
# Out:
# 0         Friday
# 1         Friday
# 2         Friday
# 3         Friday
# 4         Friday
#           ...
# 60394    Tuesday
# 60395    Tuesday
# 60396    Tuesday
# 60397    Tuesday
# 60398    Tuesday
# Name: trending_date2, Length: 60399, dtype: object

# %%
group = df.groupby([df['trending_date2'].dt.day_name(), 'categoryId'])
group

# %%
group = df.groupby([df['trending_date2'].dt.day_name(), 'categoryId'], as_index=False)
group

# %%
group = df.groupby([df['trending_date2'].dt.day_name(), 'categoryId'], as_index=False).size()
group
# Out:
#     trending_date2  categoryId  size
# 0           Friday           1   243
# 1           Friday           2   120
# 2           Friday          10   833
# 3           Friday          15   187
# 4           Friday          17   633
# ..             ...         ...   ...
# 100      Wednesday          25   468
# 101      Wednesday          26   385
# 102      Wednesday          27   212
# 103      Wednesday          28   165
# 104      Wednesday          29    12
#
# [105 rows x 3 columns]

# %%
answer = group.pivot(index='categoryId', columns = 'trending_date2')
answer
# Out:
#                  size
# trending_date2 Friday Monday Saturday Sunday Thursday Tuesday Wednesday
# categoryId
# 1                 243    263      255    274      246     257       234
# 2                 120    105      119     99      128     119       129
# 10                833    837      776    830      890     894       917
# 15                187    215      198    217      207     208       207
# 17                633    668      592    636      682     708       706
# 19                 90     92       87     91       92      89        85
# 20                283    298      296    289      282     285       291
# 22               1288   1373     1289   1337     1341    1375      1333
# 23                568    594      570    556      560     569       566
# 24               2976   3148     3066   3096     2954    3084      3090
# 25                444    453      422    437      470     452       468
# 26                369    378      364    363      375     394       385
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 6. 댓글의 수 ( comment_count )로 영상 반응에 대한 판단을 할 수 있다. <br><br> view_count 대비 댓글 수가 가장 높은 영상을 확인하라.<br><br> 단 view_count 값이 0인 경우는 제외한다.

# %%
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
target = df.loc[df.view_count != 0]
target
# Out:
#                                                    title  \
# 0                                              [신병] 물자창고
# 1       RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV
# 2           2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.
# 3                                           고기남자의 칠면조 파티
# 4      골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...
# ...                                                  ...
# 60394                       *풀코스로 먹습니다* 🍗치킨 + 🍕피자 + 🥧디저트
# 60395  [놀면 뭐하니? 예고] 우린 깐부잖아🦑 놀뭐에 등장한 월드클래스 초대손님!! MBC...
# 60396                   먹방 전쟁 : 사랑스러War (feat. 401 정육식당)
# 60397  ＂너.. 광수지?＂ 협상에 거짓말부터 던지는 광수 닮은꼴 김연경 선수 [런닝맨|21...
# 60398          ENHYPEN (엔하이픈) 'Tamed-Dashed' Official MV
#
#                   channelTitle  categoryId  view_count    likes  dislikes  \
# 0                          장삐쭈          23     1893473    38249       730
# 1      RAIN's Official Channel          10     2600864        0         0
# ...

# %%
t = target.copy()

# %%
t['ratio'] = t['comment_count'] / t['view_count']
t['ratio']
# Out:
# 0        0.004539
# 1        0.007739
# 2        0.000513
# 3        0.006566
# 4        0.006349
#            ...
# 60394    0.005792
# 60395    0.000710
# 60396    0.001701
# 60397    0.000460
# 60398    0.014212
# Name: ratio, Length: 60386, dtype: float64

# %%
t['ratio'].dropna()
# Out:
# 0        0.004539
# 1        0.007739
# 2        0.000513
# 3        0.006566
# 4        0.006349
#            ...
# 60394    0.005792
# 60395    0.000710
# 60396    0.001701
# 60397    0.000460
# 60398    0.014212
# Name: ratio, Length: 60386, dtype: float64

# %% [markdown]
# - dropna() : 결측값 있는 행 제거, dropna(axis=0)
# - 열 제거 시에는 dropna(axis=1)

# %%
result = t.sort_values(by='ratio', ascending=False)

# %%
result
# Out:
#                                                    title         channelTitle  \
# 50830               60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                  팩토리
# 51047               60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                  팩토리
# 51264               60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                  팩토리
# 52786               60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                  팩토리
# 51494               60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                  팩토리
# ...                                                  ...                  ...
# 58650                                            메밀꽃 필무렵  Lee Chanwon - Topic
# 39235              Love (Prod.Rocoberry) (러브(Prod.로코베리))         Loco - Topic
# 46801  Join the BTS #PermissiontoDance Challenge only...              YouTube
# 7265                                   뱀이 한겨울에 이러고 왔습니다.                  다흑님
# 55383                         Apple Event — September 14                Apple
#
# ...

# %%
result.iloc[0:15]
# Out:
#                                              title        channelTitle  \
# 50830         60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                 팩토리
# 51047         60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                 팩토리
# 51264         60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                 팩토리
# 52786         60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                 팩토리
# 51494         60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                 팩토리
# 52567         60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                 팩토리
# 51714         60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                 팩토리
# 52360         60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                 팩토리
# 52140         60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                 팩토리
# 51921         60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)                 팩토리
# 60036  (With Sub) 인싸'S BAR 오픈🍹🍸 : 서울에서 꼭 가봐야 할 장소✨  INSSAOPPA G [인싸오빠]
# 20619                        감사 인사 하려다가 갑자기 댓글 이벤트                 이승윤
# ...

# %%
result.iloc[0].title
# Out:
# '60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)'

# %% [markdown]
# ---

# %% [markdown]
# ### 7. 댓글 수 (comment_count)로 영상 반응에 대한 판단을 할 수 있다. <br><br> view_count 대비 댓글 수가 가장 낮은 영상을 확인하라. <br><br>단, view_count, ratio 값이 0인 경우는 제외한다.

# %%
df.columns
# Out:
# Index(['title', 'channelTitle', 'categoryId', 'view_count', 'likes',
#        'dislikes', 'comment_count', 'channelId', 'trending_date2'],
#       dtype='object')

# %%
ratio = (df['comment_count']/df['view_count']).dropna().sort_values()
ratio
# Out:
# 8319     0.0
# 49317    0.0
# 44708    0.0
# 39755    0.0
# 39769    0.0
#         ...
# 526      inf
# 1180     inf
# 957      inf
# 740      inf
# 297      inf
# Length: 60392, dtype: float64

# %%
ratio[ratio!=0][0]
# Out:
# 0.0045392778243999255

# %%
result = df.iloc[ratio[ratio!=0].index[0]].title
result
# Out:
# 'Join the BTS #PermissiontoDance Challenge only on YouTube #Shorts'

# %% [markdown]
# ---

# %% [markdown]
# ### 8. 가장 많은 트렌드 영상을 제작한 채널 이름은 무엇인가? 날짜 기준, 중복 포함

# %%
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
df.columns
# Out:
# Index(['title', 'channelTitle', 'categoryId', 'view_count', 'likes',
#        'dislikes', 'comment_count', 'channelId', 'trending_date2'],
#       dtype='object')

# %%
df.channelId.value_counts()
# Out:
# UCszFjh7CEfwDb7UUGb4RzCQ    372
# UClzB2iZ5jPoTNz0S-QU6Wiw    318
# UCtm_QoN2SIxwCE-59shX7Qg    318
# UCaKod3X1Tn4c7Ci0iUKcvzQ    313
# UCiwQRG2sCcfjKkgxMEdJGPg    293
#                            ...
# UCj00eA-Q0lokXCA6JAa_grw      1
# UCdtY7-_h-KgBTXHJfTk8wwQ      1
# UCESC_GRUe4Z7-OOxk_AWm5Q      1
# UCGuE0TrBNIZKfordUwAQe2w      1
# UCNh_yWrspnQbZDZijQFyjbw      1
# Name: channelId, Length: 1770, dtype: int64

# %%
df.channelId.value_counts().index[0]
# Out:
# 'UCszFjh7CEfwDb7UUGb4RzCQ'

# %%
df.loc[df.channelId == df.channelId.value_counts().index[0]]
# Out:
#                                  title channelTitle  categoryId  view_count  \
# 76                           [병영일기] 부식           짤툰           1     1496529
# 325                          [병영일기] 부식           짤툰           1     1518445
# 558                          [병영일기] 부식           짤툰           1     1537676
# 778                          [병영일기] 부식           짤툰           1     1553145
# 999                          [병영일기] 부식           짤툰           1     1565338
# ...                                ...          ...         ...         ...
# 55966  [짐승친구들] 추석 특집! 욕쟁이 앵무새 VS 짐승친구들           짤툰           1     1419688
# 56195  [짐승친구들] 추석 특집! 욕쟁이 앵무새 VS 짐승친구들           짤툰           1     1450622
# 59814                   [짐승친구들] 느그 이름은           짤툰           1     1014334
# 60033                   [짐승친구들] 느그 이름은           짤툰           1     1237262
# 60241                   [짐승친구들] 느그 이름은           짤툰           1     1374286
#
# ...

# %%
df.loc[df.channelId==df.channelId.value_counts().index[0]].channelTitle
# Out:
# 76       짤툰
# 325      짤툰
# 558      짤툰
# 778      짤툰
# 999      짤툰
#          ..
# 55966    짤툰
# 56195    짤툰
# 59814    짤툰
# 60033    짤툰
# 60241    짤툰
# Name: channelTitle, Length: 372, dtype: object

# %%
a = df.loc[df.channelId==df.channelId.value_counts().index[0]].channelTitle.unique()
a
# Out:
# array(['짤툰'], dtype=object)

# %% [markdown]
# ------

# %% [markdown]
# ### 9. 20일 이상 인기 동영상 리스트에 포함된 동영상 숫자는?

# %%
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
df.columns
# Out:
# Index(['title', 'channelTitle', 'categoryId', 'view_count', 'likes',
#        'dislikes', 'comment_count', 'channelId', 'trending_date2'],
#       dtype='object')

# %%
df['title']
# Out:
# 0                                                [신병] 물자창고
# 1         RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV
# 2             2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.
# 3                                             고기남자의 칠면조 파티
# 4        골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...
#                                ...
# 60394                         *풀코스로 먹습니다* 🍗치킨 + 🍕피자 + 🥧디저트
# 60395    [놀면 뭐하니? 예고] 우린 깐부잖아🦑 놀뭐에 등장한 월드클래스 초대손님!! MBC...
# 60396                     먹방 전쟁 : 사랑스러War (feat. 401 정육식당)
# 60397    ＂너.. 광수지?＂ 협상에 거짓말부터 던지는 광수 닮은꼴 김연경 선수 [런닝맨|21...
# 60398            ENHYPEN (엔하이픈) 'Tamed-Dashed' Official MV
# Name: title, Length: 60399, dtype: object

# %%
df[['title', 'channelId']]
# Out:
#                                                    title  \
# 0                                              [신병] 물자창고
# 1       RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV
# 2           2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.
# 3                                           고기남자의 칠면조 파티
# 4      골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...
# ...                                                  ...
# 60394                       *풀코스로 먹습니다* 🍗치킨 + 🍕피자 + 🥧디저트
# 60395  [놀면 뭐하니? 예고] 우린 깐부잖아🦑 놀뭐에 등장한 월드클래스 초대손님!! MBC...
# 60396                   먹방 전쟁 : 사랑스러War (feat. 401 정육식당)
# 60397  ＂너.. 광수지?＂ 협상에 거짓말부터 던지는 광수 닮은꼴 김연경 선수 [런닝맨|21...
# 60398          ENHYPEN (엔하이픈) 'Tamed-Dashed' Official MV
#
#                       channelId
# 0      UChbE5OZQ6dRHECsX0tEPEZQ
# 1      UCxXgIeE5hxWxHG6dz9Scg2w
# 2      UCZUPZW5idAxYp-Asj__lVAA
# 3      UCT3CumbFIJiW33uq0UI3zlg
# 4      UCdWgRSfttvDucq4ApcCg5Mw
# ...                         ...
# 60394  UCWf4QKgnTyvmehcRqw-JldQ
# ...

# %%
df[['title', 'channelId']].value_counts()
# Out:
# title                                                           channelId
# 컵라면 먹을 때 절대 일어날리 없는 상황들 ㅋㅋㅋ                                     UCmzMtXrJgfCqA0rfhz8_P4A    24
# 대한민국 VS 투르크메니스탄 : FIFA 카타르 월드컵 2차 예선 하이라이트 - 2021.06.05         UCpjOmwiy88a9EV3Rv8ukJgw    24
# 극과 극을 살고 있는 인도의 갑부와 빈곤층들!                                       UCi9Sl8GnFdYoqEVXnojBPJw    23
# 2주더놀릴예정                                                         UCaKod3X1Tn4c7Ci0iUKcvzQ    23
# 대박... 멧돼지를 아들로 삼은 할아버지｜KBS 주주클럽 050410 방송                       UCAhKKbDO9-ymWZ_7iAFLBQQ    23
#                                                                                             ..
# 천재 친구 황봉황 [총몇명 스토리2]                                            UCRuSxVu4iqTK5kCh90ntAgA     1
# 담배충 [병맛더빙/웃긴영상]                                                 UCUK4YjvUvHrFQwTFXwkUIng     1
# Official Trailer | The Falcon and The Winter Soldier | Disney+  UCvC4D8onUfXzvjTOM-dBfEA     1
# ...

# %%
answer= (df[['title','channelId']].value_counts()>=20).sum()
answer
# Out:
# 40

# %%
(df[['title', 'channelId']].value_counts()>=20).sum()
# Out:
# 40

# %% [markdown]
# - sum()
# sum(axis=None,skipna=None,level=None,numeric_only=None,min_count=0,**kwargs)
#
# - axis, axis=0 - 행 | axis=1 - 열
# - skipna, NaN값을 제외하거나 NaN값을 포함
# - level, 축이 MultiIndex인 경우 특정 수준과 함께 계산
# - numeric_only, True일 경우 float, int 및 boolean 열만 포함
# - min_count, 정수. 합계를 계산하기 위한 비 NaN값의 최소 갯수. 이 조건이 충족되지 않으면 합계는 NaN
# - **kwargs, 함수에 대한 추가 키워드 인수
